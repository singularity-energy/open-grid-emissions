# %% [markdown]
# This notebook is used to create zip files that are used for archiving and uploading data to the S3 bucket.

# %%
# %reload_ext autoreload
# %autoreload 2

# # Tell python where to look for modules.
import sys

sys.path.append("../../src")

import oge.output_data as output_data

# %%
list(range(2005, 2019))
# Out:
# [2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018]

# %%
# zip all data for s3 and zenodo
years = [
    2005,
    2006,
    2007,
    2008,
    2009,
    2010,
    2011,
    2012,
    2013,
    2014,
    2015,
    2016,
    2017,
    2018,
    2019,
    2020,
    2021,
    2022,
]

output_data.prepare_files_for_upload(years)

# %%
output_data.zip_results_for_s3()
# Out:
# 2024-08-03 12:30:34 [INFO] oge.oge.output_data:81 zipping 2005-2018_power_sector_data_monthly_metric_units for s3
# 2024-08-03 12:30:44 [INFO] oge.oge.output_data:81 zipping 2005-2018_power_sector_data_monthly_us_units for s3
# 2024-08-03 12:30:53 [INFO] oge.oge.output_data:81 zipping 2005-2018_power_sector_data_annual_metric_units for s3
# 2024-08-03 12:31:01 [INFO] oge.oge.output_data:81 zipping 2005-2018_power_sector_data_annual_us_units for s3
# 2024-08-03 12:31:09 [INFO] oge.oge.output_data:81 zipping 2005-2018_carbon_accounting_monthly_metric_units for s3
# 2024-08-03 12:31:09 [INFO] oge.oge.output_data:81 zipping 2005-2018_carbon_accounting_monthly_us_units for s3
# 2024-08-03 12:31:09 [INFO] oge.oge.output_data:81 zipping 2005-2018_carbon_accounting_annual_metric_units for s3
# 2024-08-03 12:31:09 [INFO] oge.oge.output_data:81 zipping 2005-2018_carbon_accounting_annual_us_units for s3
# 2024-08-03 12:31:09 [INFO] oge.oge.output_data:81 zipping 2005-2018_plant_data_monthly_metric_units for s3
# 2024-08-03 12:31:14 [INFO] oge.oge.output_data:81 zipping 2005-2018_plant_data_monthly_us_units for s3
# 2024-08-03 12:31:19 [INFO] oge.oge.output_data:81 zipping 2005-2018_plant_data_annual_metric_units for s3
# 2024-08-03 12:31:20 [INFO] oge.oge.output_data:81 zipping 2005-2018_plant_data_annual_us_units for s3
# 2024-08-03 12:31:22 [INFO] oge.oge.output_data:169 zipping 2019_power_sector_data_hourly_metric_units for s3
# 2024-08-03 12:31:45 [INFO] oge.oge.output_data:169 zipping 2019_power_sector_data_hourly_us_units for s3
# 2024-08-03 12:32:09 [INFO] oge.oge.output_data:169 zipping 2019_power_sector_data_monthly_metric_units for s3
# 2024-08-03 12:32:10 [INFO] oge.oge.output_data:169 zipping 2019_power_sector_data_monthly_us_units for s3
# 2024-08-03 12:32:10 [INFO] oge.oge.output_data:169 zipping 2019_power_sector_data_annual_metric_units for s3
# 2024-08-03 12:32:10 [INFO] oge.oge.output_data:169 zipping 2019_power_sector_data_annual_us_units for s3
# 2024-08-03 12:32:11 [INFO] oge.oge.output_data:169 zipping 2019_carbon_accounting_hourly_metric_units for s3
# 2024-08-03 12:32:14 [INFO] oge.oge.output_data:169 zipping 2019_carbon_accounting_hourly_us_units for s3
# 2024-08-03 12:32:17 [INFO] oge.oge.output_data:169 zipping 2019_carbon_accounting_monthly_metric_units for s3
# 2024-08-03 12:32:18 [INFO] oge.oge.output_data:169 zipping 2019_carbon_accounting_monthly_us_units for s3
# 2024-08-03 12:32:18 [INFO] oge.oge.output_data:169 zipping 2019_carbon_accounting_annual_metric_units for s3
# 2024-08-03 12:32:18 [INFO] oge.oge.output_data:169 zipping 2019_carbon_accounting_annual_us_units for s3
# 2024-08-03 12:32:19 [INFO] oge.oge.output_data:169 zipping 2019_plant_data_hourly_us_units for s3
# 2024-08-03 12:34:24 [INFO] oge.oge.output_data:169 zipping 2019_plant_data_monthly_metric_units for s3
# 2024-08-03 12:34:25 [INFO] oge.oge.output_data:169 zipping 2019_plant_data_monthly_us_units for s3
# 2024-08-03 12:34:25 [INFO] oge.oge.output_data:169 zipping 2019_plant_data_annual_metric_units for s3
# 2024-08-03 12:34:25 [INFO] oge.oge.output_data:169 zipping 2019_plant_data_annual_us_units for s3
# 2024-08-03 12:34:25 [INFO] oge.oge.output_data:169 zipping 2020_power_sector_data_hourly_metric_units for s3
# 2024-08-03 12:34:50 [INFO] oge.oge.output_data:169 zipping 2020_power_sector_data_hourly_us_units for s3
# 2024-08-03 12:35:16 [INFO] oge.oge.output_data:169 zipping 2020_power_sector_data_monthly_metric_units for s3
# 2024-08-03 12:35:16 [INFO] oge.oge.output_data:169 zipping 2020_power_sector_data_monthly_us_units for s3
# 2024-08-03 12:35:17 [INFO] oge.oge.output_data:169 zipping 2020_power_sector_data_annual_metric_units for s3
# 2024-08-03 12:35:18 [INFO] oge.oge.output_data:169 zipping 2020_power_sector_data_annual_us_units for s3
# 2024-08-03 12:35:18 [INFO] oge.oge.output_data:169 zipping 2020_carbon_accounting_hourly_metric_units for s3
# 2024-08-03 12:35:21 [INFO] oge.oge.output_data:169 zipping 2020_carbon_accounting_hourly_us_units for s3
# 2024-08-03 12:35:25 [INFO] oge.oge.output_data:169 zipping 2020_carbon_accounting_monthly_metric_units for s3
# 2024-08-03 12:35:25 [INFO] oge.oge.output_data:169 zipping 2020_carbon_accounting_monthly_us_units for s3
# 2024-08-03 12:35:25 [INFO] oge.oge.output_data:169 zipping 2020_carbon_accounting_annual_metric_units for s3
# 2024-08-03 12:35:26 [INFO] oge.oge.output_data:169 zipping 2020_carbon_accounting_annual_us_units for s3
# 2024-08-03 12:35:26 [INFO] oge.oge.output_data:169 zipping 2020_plant_data_hourly_us_units for s3
# 2024-08-03 12:37:52 [INFO] oge.oge.output_data:169 zipping 2020_plant_data_monthly_metric_units for s3
# 2024-08-03 12:37:52 [INFO] oge.oge.output_data:169 zipping 2020_plant_data_monthly_us_units for s3
# 2024-08-03 12:37:53 [INFO] oge.oge.output_data:169 zipping 2020_plant_data_annual_metric_units for s3
# 2024-08-03 12:37:53 [INFO] oge.oge.output_data:169 zipping 2020_plant_data_annual_us_units for s3
# 2024-08-03 12:37:53 [INFO] oge.oge.output_data:169 zipping 2021_power_sector_data_hourly_metric_units for s3
# 2024-08-03 12:38:18 [INFO] oge.oge.output_data:169 zipping 2021_power_sector_data_hourly_us_units for s3
# 2024-08-03 12:38:44 [INFO] oge.oge.output_data:169 zipping 2021_power_sector_data_monthly_metric_units for s3
# 2024-08-03 12:38:45 [INFO] oge.oge.output_data:169 zipping 2021_power_sector_data_monthly_us_units for s3
# 2024-08-03 12:38:45 [INFO] oge.oge.output_data:169 zipping 2021_power_sector_data_annual_metric_units for s3
# 2024-08-03 12:38:46 [INFO] oge.oge.output_data:169 zipping 2021_power_sector_data_annual_us_units for s3
# 2024-08-03 12:38:46 [INFO] oge.oge.output_data:169 zipping 2021_carbon_accounting_hourly_metric_units for s3
# 2024-08-03 12:38:50 [INFO] oge.oge.output_data:169 zipping 2021_carbon_accounting_hourly_us_units for s3
# 2024-08-03 12:38:53 [INFO] oge.oge.output_data:169 zipping 2021_carbon_accounting_monthly_metric_units for s3
# 2024-08-03 12:38:54 [INFO] oge.oge.output_data:169 zipping 2021_carbon_accounting_monthly_us_units for s3
# 2024-08-03 12:38:54 [INFO] oge.oge.output_data:169 zipping 2021_carbon_accounting_annual_metric_units for s3
# 2024-08-03 12:38:54 [INFO] oge.oge.output_data:169 zipping 2021_carbon_accounting_annual_us_units for s3
# 2024-08-03 12:38:55 [INFO] oge.oge.output_data:169 zipping 2021_plant_data_hourly_us_units for s3
# 2024-08-03 12:41:39 [INFO] oge.oge.output_data:169 zipping 2021_plant_data_monthly_metric_units for s3
# 2024-08-03 12:41:40 [INFO] oge.oge.output_data:169 zipping 2021_plant_data_monthly_us_units for s3
# 2024-08-03 12:41:40 [INFO] oge.oge.output_data:169 zipping 2021_plant_data_annual_metric_units for s3
# 2024-08-03 12:41:40 [INFO] oge.oge.output_data:169 zipping 2021_plant_data_annual_us_units for s3
# 2024-08-03 12:41:41 [INFO] oge.oge.output_data:169 zipping 2022_power_sector_data_hourly_metric_units for s3
# 2024-08-03 12:42:07 [INFO] oge.oge.output_data:169 zipping 2022_power_sector_data_hourly_us_units for s3
# 2024-08-03 12:42:34 [INFO] oge.oge.output_data:169 zipping 2022_power_sector_data_monthly_metric_units for s3
# 2024-08-03 12:42:34 [INFO] oge.oge.output_data:169 zipping 2022_power_sector_data_monthly_us_units for s3
# 2024-08-03 12:42:35 [INFO] oge.oge.output_data:169 zipping 2022_power_sector_data_annual_metric_units for s3
# 2024-08-03 12:42:35 [INFO] oge.oge.output_data:169 zipping 2022_power_sector_data_annual_us_units for s3
# 2024-08-03 12:42:36 [INFO] oge.oge.output_data:169 zipping 2022_carbon_accounting_hourly_metric_units for s3
# 2024-08-03 12:42:39 [INFO] oge.oge.output_data:169 zipping 2022_carbon_accounting_hourly_us_units for s3
# 2024-08-03 12:42:43 [INFO] oge.oge.output_data:169 zipping 2022_carbon_accounting_monthly_metric_units for s3
# 2024-08-03 12:42:43 [INFO] oge.oge.output_data:169 zipping 2022_carbon_accounting_monthly_us_units for s3
# 2024-08-03 12:42:44 [INFO] oge.oge.output_data:169 zipping 2022_carbon_accounting_annual_metric_units for s3
# 2024-08-03 12:42:44 [INFO] oge.oge.output_data:169 zipping 2022_carbon_accounting_annual_us_units for s3
# 2024-08-03 12:42:44 [INFO] oge.oge.output_data:169 zipping 2022_plant_data_hourly_us_units for s3
# 2024-08-03 12:45:40 [INFO] oge.oge.output_data:169 zipping 2022_plant_data_monthly_metric_units for s3
# 2024-08-03 12:45:40 [INFO] oge.oge.output_data:169 zipping 2022_plant_data_monthly_us_units for s3
# 2024-08-03 12:45:41 [INFO] oge.oge.output_data:169 zipping 2022_plant_data_annual_metric_units for s3
# 2024-08-03 12:45:41 [INFO] oge.oge.output_data:169 zipping 2022_plant_data_annual_us_units for s3

# %%
# option: just zip results for s3
for year in [2019, 2020, 2021, 2022]:
    output_data.zip_results_for_s3(year)

# %%
# option: just zip results for zenodo
for year in [2019, 2020, 2021, 2022]:
    output_data.zip_data_for_zenodo(year)
