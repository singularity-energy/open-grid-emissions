# %%
# Tell python where to look for modules. 
# Depending on how your jupyter handles working directories, this may not be needed.
import sys
sys.path.append('../../hourly-egrid/')

# import the necessary packages
# %reload_ext autoreload
# %autoreload 2

# import packages
import os
import requests
import tarfile
import sqlalchemy as sa
from pathlib import Path
import pandas as pd
import plotly.express as px
import numpy as np

import src.data_cleaning as data_cleaning
import src.load_data as load_data
# Out:
# C:\Users\Greg\miniconda3\envs\hourly_egrid\lib\site-packages\statsmodels\compat\pandas.py:61: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
# add code to download eia data

# %%
year = 2020

# %%
# load plant level data from egrid
egrid_plant = pd.read_excel(f'../data/egrid/egrid{year}_data.xlsx', 
                            sheet_name=f'PLNT{str(year)[-2:]}', 
                            header=1, 
                            usecols=['BACODE','PSTATABB', 'ORISPL', 'PNAME','PLGENATN', 'PLGENATR', 'PLHTIANT','UNCO2','PLCO2AN'])
# calculate total net generation
egrid_plant['net_generation_mwh'] = egrid_plant['PLGENATN'] + egrid_plant['PLGENATR']
egrid_plant = egrid_plant.drop(columns=['PLGENATN', 'PLGENATR'])
# rename the columns
egrid_plant = egrid_plant.rename(columns={'BACODE':'ba_code',
                                          'PSTATABB':'state',
                                          'ORISPL':'plant_id_eia',
                                          'PNAME':'plant_name',
                                          'PLHTIANT':'heat_input_mmbtu',
                                          'UNCO2':'co2_mass_tons_unadjusted',
                                          'PLCO2AN':'co2_mass_tons'})
# reorder the columns                                         
egrid_plant = egrid_plant[['ba_code', 'state', 'plant_id_eia', 'plant_name', 'net_generation_mwh', 'heat_input_mmbtu', 'co2_mass_tons', 'co2_mass_tons_unadjusted']]

# %%
egrid_plant
# Out:
#       ba_code state  plant_id_eia                        plant_name  \
# 0         NaN    AK         60814         7-Mile Ridge Wind Project
# 1         NaN    AK         54452  Agrium Kenai Nitrogen Operations
# 2         NaN    AK         57053                          Alakanuk
# 3         NaN    AK         58982               Allison Creek Hydro
# 4         NaN    AK         60243                            Ambler
# ...       ...   ...           ...                               ...
# 12663    WACM    WY         57967   Western Sugar Coop - Torrington
# 12664    WACM    WY         55479                           Wygen I
# 12665    WACM    WY         56319                          Wygen II
# 12666    WACM    WY         56596                         Wygen III
# 12667    PACE    WY          6101                            Wyodak
#
#        net_generation_mwh  heat_input_mmbtu  co2_mass_tons  \
# 0                     NaN               NaN            NaN
# 1                     NaN               NaN            NaN
# 2                   0.000               NaN            NaN
# 3               20808.000      1.825500e+05            NaN
# 4                1212.000      1.155500e+04        943.616
# ...                   ...               ...            ...
# 12663                 NaN               NaN            NaN
# 12664          699013.998      8.761069e+06     918861.688
# 12665          716788.996      8.916959e+06     935205.875
# 12666          843013.000      9.668216e+06    1014000.875
# 12667         1730471.955      2.229280e+07    2338068.000
#
#        co2_mass_tons_unadjusted
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                       943.616
# ...                         ...
# 12663                       NaN
# 12664                918861.688
# 12665                935205.875
# 12666               1014000.875
# 12667               2338068.000
#
# [12668 rows x 8 columns]

# %%
eia_emissions = pd.read_excel(f'../data/eia/emissions{year}.xlsx', 
                                sheet_name='CO2', 
                                header=1, 
                                skipfooter=2,
                                usecols=['Plant Code','Plant Name','State', 'Generation (kWh)','Total Fuel Consumption (MMBtu)', 'Tons of CO2 Emissions','Balancing Authority Code'])

eia_emissions = eia_emissions.rename(columns={'Plant Code':'plant_id_eia',
                                              'Plant Name':'plant_name',
                                              'State':'state', 
                                              'Generation (kWh)':'net_generation_mwh',
                                              'Total Fuel Consumption (MMBtu)':'heat_input_mmbtu', 
                                              'Tons of CO2 Emissions':'co2_mass_tons_unadjusted',
                                              'Balancing Authority Code':'ba_code'})

eia_emissions['net_generation_mwh'] = eia_emissions['net_generation_mwh'] / 1000

eia_emissions = eia_emissions.groupby(['ba_code','state','plant_id_eia','plant_name'], dropna=False).sum().reset_index()

eia_emissions
# Out:
#      ba_code state  plant_id_eia                         plant_name  \
# 0        AEC    AL            56               Lowman Energy Center
# 1        AEC    AL           533                         McWilliams
# 2        AEC    AL          7063                      McIntosh (AL)
# 3       AECI    AR         55340                 Dell Power Station
# 4       AECI    IA          1127                         Bloomfield
# ...      ...   ...           ...                                ...
# 3165     NaN    HI         56055                    Hana Substation
# 3166     NaN    HI         56258               Kapaia Power Station
# 3167     NaN    HI         56329           Campbell Industrial Park
# 3168     NaN    HI         59035  Biomass to Energy Facility, Kauai
# 3169     NaN    RI          6567                       Block Island
#
#       net_generation_mwh  heat_input_mmbtu  co2_mass_tons_unadjusted
# 0             317291.000           4163218              4.268872e+05
# 1            4158113.000          30970570              1.806303e+06
# 2             369974.000           4200371              2.449897e+05
# 3            2774720.000          20367675              1.187908e+06
# 4                 56.000               645              5.271279e+01
# ...                  ...               ...                       ...
# 3165             124.000              1395              1.140067e+02
# 3166           16868.596            151313              1.236609e+04
# 3167           83712.000           1410821              1.152997e+05
# 3168             140.140              1860              1.520090e+02
# 3169               4.000                48              3.922813e+00
#
# [3170 rows x 7 columns]

# %%
plants_not_in_eia = list(set(egrid_plant['plant_id_eia'].unique()) - set(eia_emissions['plant_id_eia'].unique()))
plants_not_in_egrid = list(set(eia_emissions['plant_id_eia'].unique()) - set(egrid_plant['plant_id_eia'].unique()))

# %%
egrid_plant[(egrid_plant['plant_id_eia'].isin(plants_not_in_eia)) & (egrid_plant['co2_mass_tons_unadjusted'] > 0)]
# Out:
#       ba_code state  plant_id_eia                              plant_name  \
# 177       TVA    AL         58061  Decatur-Morgan Co LFG Recovery Project
# 223       TVA    AL         59710               Sand Valley Power Station
# 235      SOCO    AL         57467             Westervelt Moundville Cogen
# 303      MISO    AR         56079       Riceland Foods Cogeneration Plant
# 311      MISO    AR         56523          Two Pine Landfill Gas Recovery
# ...       ...   ...           ...                                     ...
# 12503    MISO    WI         56525           Timberline Trail Gas Recovery
# 12512    MISO    WI         58747                     Viresco Turtle Lake
# 12530    MISO    WI         50936           Winnebago County Landfill Gas
# 12577     PJM    WV         63246                  New River Clean Energy
# 12611    PACE    WY         52127                Elk Basin Gasoline Plant
#
#        net_generation_mwh  heat_input_mmbtu  co2_mass_tons  \
# 177              12862.00        137357.000          0.000
# 223              24443.00        360361.008          0.001
# 235              32244.00        185500.529          0.004
# 303              12874.00         78686.454          0.001
# 311              28810.00        368965.992          0.000
# ...                   ...               ...            ...
# 12503            19434.00        244885.000          0.000
# 12512             9209.00         46572.190          0.000
# 12530            17073.00        114884.018          0.000
# 12577             6457.00         29111.000          0.000
# 12611             9238.28         51635.570       3017.841
#
#        co2_mass_tons_unadjusted
# 177                    8722.140
# 223                   22882.849
# 235                  135928.422
# 303                  187364.062
# 311                   23429.262
# ...                         ...
# 12503                 15550.145
# 12512                  7621.118
# 12530                 12690.751
# 12577                  1848.542
# 12611                 34133.457
#
# [424 rows x 8 columns]

# %%
eia_emissions[(eia_emissions['plant_id_eia'].isin(plants_not_in_egrid))]
# Out:
#      ba_code state  plant_id_eia                           plant_name  \
# 232     CISO    CA         55874                       Panoche Peaker
# 299     CISO    CA         57901         El Segundo Energy Center LLC
# 328     CISO    CA         59002               Carlsbad Energy Center
# 402     CPLE    NC          7538          Wayne County Energy Complex
# 418     CPLE    NC         58697            L V Sutton Combined Cycle
# 474      DUK    NC         58215             Lee Combined Cycle Plant
# 545     ERCO    TX          7512                 Arthur Von Rosenberg
# 614     ERCO    TX         55545                Hidalgo Energy Center
# 770     ISNE    CT         57068               GenConn Middletown LLC
# 1191    MISO    IN         10397    ArcelorMittal Indiana Harbor West
# 1200    MISO    IN         54995        Indiana Harbor E 5 AC Station
# 1222    MISO    LA          1393                           R S Nelson
# 1324    MISO    MI          7268                    491 E 48th Street
# 1556    MISO    TX         10789                   Sabine River Works
# 1605    MISO    WI          7799                    West Marinette 34
# 1737    NYIS    NY          7784                       Allegany Cogen
# 1812    NYIS    NY         57664                    Astoria Energy II
# 2569    SOCO    GA          7709                             Dahlberg
# 2594    SOCO    GA         54538             Hartwell Energy Facility
# 2643     SRP    AZ         58557  Mesquite Generating Station Block 1
# 2644     SRP    AZ         59338             Gila River Power Block 1
# 2758    SWPP    LA         56565                   J Lamar Stall Unit
# 2887    SWPP    OK          7546                           Ponca City
# 2960    TEPC    AZ         59784             Gila River Power Block 3
#
#       net_generation_mwh  heat_input_mmbtu  co2_mass_tons_unadjusted
# 232             3826.000             58814              3.430222e+03
# 299           395756.000           3558364              2.075353e+05
# 328           388042.000           4424921              2.580757e+05
# 402           175398.000           2067503              1.221204e+05
# 418          4078353.000          29520555              1.721822e+06
# 474          5654012.000          42170811              2.459538e+06
# 545          3187965.000          22400959              1.306496e+06
# 614          2529351.000          19000365              1.108163e+06
# 770              693.000             43009              3.339597e+03
# 1191           90853.631           3701661              2.158928e+05
# 1200           50467.656           1225670              7.148502e+04
# 1222         2077118.000          25086353              2.757748e+06
# 1324           59950.000            673022              3.925281e+04
# 1556         2420707.010          21761362              1.269193e+06
# 1605           92138.000           1164182              6.789885e+04
# 1737           18211.000            152073              8.869387e+03
# 1812         2872031.000          21093651              1.230369e+06
# 2569          512046.000           6239451              3.639806e+05
# 2594          186874.000           2263571              1.321489e+05
# 2643         3360316.000          24761084              1.444146e+06
# 2644         3165264.000          22846200              1.332464e+06
# 2758         3473383.000          24940662              1.454620e+06
# 2887           13132.000            132678              7.738208e+03
# 2960         2835616.000          21404592              1.248385e+06

# %%
percent_diff = eia_emissions[['plant_id_eia','co2_mass_tons_unadjusted']].merge(egrid_plant[['plant_id_eia','co2_mass_tons_unadjusted']], how='outer', on='plant_id_eia', suffixes=('_eia','_egrid')).fillna(0)
percent_diff['percent_diff'] = (percent_diff['co2_mass_tons_unadjusted_eia'] - percent_diff['co2_mass_tons_unadjusted_egrid']) / percent_diff['co2_mass_tons_unadjusted_egrid']
percent_diff = percent_diff.replace(np.inf,1)
percent_diff.loc[percent_diff['percent_diff'] > 1, 'percent_diff'] = 1
percent_diff
# Out:
#        plant_id_eia  co2_mass_tons_unadjusted_eia  \
# 0                56                  4.268872e+05
# 1               533                  1.806303e+06
# 2              7063                  2.449897e+05
# 3             55340                  1.187908e+06
# 4              1127                  5.271279e+01
# ...             ...                           ...
# 12687         62516                  0.000000e+00
# 12688         57327                  0.000000e+00
# 12689         56093                  0.000000e+00
# 12690         63972                  0.000000e+00
# 12691         57967                  0.000000e+00
#
#        co2_mass_tons_unadjusted_egrid  percent_diff
# 0                          414894.312      0.028906
# 1                         1776162.656      0.016970
# 2                          237737.302      0.030506
# 3                         1275819.438     -0.068906
# 4                              38.753      0.360225
# ...                               ...           ...
# 12687                           0.000           NaN
# 12688                           0.000           NaN
# 12689                           0.000           NaN
# 12690                           0.000           NaN
# 12691                           0.000           NaN
#
# [12692 rows x 4 columns]

# %%
px.histogram(percent_diff, x='percent_diff', nbins=40, range_x=[-1,1], width=800, title='Number of plants by percent difference between EIA and eGRID').update_xaxes(dtick=0.1, tick0=0.05).add_vline(x=0)

# %%
eia_emissions.groupby('ba_code').sum()['co2_mass_tons_unadjusted']
# Out:
# ba_code
# AEC     2.478180e+06
# AECI    1.786504e+07
# AVA     1.151475e+06
# AVRN    1.183976e+06
# AZPS    1.469719e+07
# BANC    2.703297e+06
# BPAT    1.096445e+07
# CISO    3.974728e+07
# CPLE    1.599850e+07
# CSTO    1.657885e+06
# DEAA    9.098123e+05
# DUK     2.924707e+07
# EEI     4.513089e+06
# EPE     2.866484e+06
# ERCO    1.829199e+08
# FMPP    9.040570e+06
# FPC     2.194937e+07
# FPL     4.157300e+07
# GRIF    1.003217e+06
# GVL     1.061437e+06
# HST     4.421561e+02
# IID     5.975766e+05
# IPCO    1.414436e+06
# ISNE    2.749965e+07
# JEA     7.404762e+06
# LDWP    1.122695e+07
# LGEE    3.083305e+07
# MISO    3.695482e+08
# NBSO    1.244135e+05
# NEVP    1.436806e+07
# NSB     5.884219e+00
# NWMT    1.111678e+07
# NYIS    3.263924e+07
# OVEC    1.023809e+07
# PACE    4.728161e+07
# PACW    1.051130e+06
# PGE     5.307620e+06
# PJM     3.087753e+08
# PNM     7.802419e+06
# PSCO    1.520822e+07
# PSEI    3.126455e+06
# SC      1.213508e+07
# SCEG    1.018206e+07
# SCL     9.078981e+04
# SEC     8.700669e+06
# SOCO    1.044267e+08
# SPA     1.818873e+06
# SRP     1.669714e+07
# SWPP    1.304951e+08
# TAL     1.240110e+06
# TEC     1.048042e+07
# TEPC    1.094330e+07
# TIDC    7.260273e+05
# TPWR    2.863111e+04
# TVA     4.632361e+07
# WACM    3.384011e+07
# WALC    3.800428e+06
# Name: co2_mass_tons_unadjusted, dtype: float64

# %%
percent_diff_ba = eia_emissions.groupby('ba_code', dropna=False).sum()['co2_mass_tons_unadjusted'].reset_index().merge(egrid_plant.groupby('ba_code', dropna=False).sum()['co2_mass_tons_unadjusted'].reset_index(), how='outer', on='ba_code', suffixes=('_eia','_egrid'))
percent_diff_ba = percent_diff_ba.set_index('ba_code')
percent_diff_ba = percent_diff_ba.fillna(0)
percent_diff_ba['percent_diff'] = (percent_diff_ba['co2_mass_tons_unadjusted_eia'] - percent_diff_ba['co2_mass_tons_unadjusted_egrid']) / percent_diff_ba['co2_mass_tons_unadjusted_egrid']
percent_diff_ba = percent_diff_ba.replace(np.inf,1)
percent_diff_ba.loc[percent_diff_ba['percent_diff'] > 1, 'percent_diff'] = 1
percent_diff_ba
# Out:
#          co2_mass_tons_unadjusted_eia  co2_mass_tons_unadjusted_egrid  \
# ba_code
# AEC                      2.478180e+06                    2.459531e+06
# AECI                     1.786504e+07                    1.817683e+07
# AVA                      1.151475e+06                    3.418281e+06
# AVRN                     1.183976e+06                    1.247514e+06
# AZPS                     1.469719e+07                    1.484023e+07
# ...                               ...                             ...
# HGMA                     0.000000e+00                    0.000000e+00
# SEPA                     0.000000e+00                    4.411831e+04
# WAUW                     0.000000e+00                    0.000000e+00
# WWA                      0.000000e+00                    0.000000e+00
# YAD                      0.000000e+00                    0.000000e+00
#
#          percent_diff
# ba_code
# AEC          0.007582
# AECI        -0.017153
# AVA         -0.663142
# AVRN        -0.050932
# AZPS        -0.009639
# ...               ...
# HGMA              NaN
# SEPA        -1.000000
# WAUW              NaN
# WWA               NaN
# YAD               NaN
#
# [72 rows x 3 columns]

# %%
px.histogram(percent_diff_ba, x='percent_diff', nbins=40, range_x=[-1,1], width=800, title='Number of BAs by percent difference between EIA and eGRID').update_xaxes(dtick=0.1, tick0=0.05).add_vline(x=0)
